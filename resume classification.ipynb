# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 3A3B-B1C3
#
#  Directory of C:\Users\Dell\EXCELR\Resume Classification NLP Project
#
# 15-03-2023  23:30    <DIR>          .
# 08-03-2023  13:01    <DIR>          ..
# 15-03-2023  22:34    <DIR>          .ipynb_checkpoints
# 15-03-2023  23:30         2,325,255 resume classification.ipynb
# 12-03-2023  16:19           423,388 resumes.csv
# 12-03-2023  16:20           186,787 scraping data from resume.ipynb
# 03-03-2023  11:15            91,728 Untitled.ipynb
# 15-03-2023  22:31           288,542 xgboost_model.pkl
#                5 File(s)      3,315,700 bytes
#                3 Dir(s)  149,820,334,080 bytes free

# %%
data=pd.read_csv("resumes.csv")
data=data.drop("Unnamed: 0",axis=1)
data
# Out:
#                                               Resumes Catagory
# 0   Name: Ravali P                                ...  Reactjs
# 1   SUSOVAN  BAG    Seeking  a  challenging  posit...  Reactjs
# 2   Kanumuru Deepak Reddy   CAREER OBJECTIVE: To s...  Reactjs
# 3   HARIPRIYA BATTINA  Experience as UI Developer ...  Reactjs
# 4   KAMALAKAR REDDY. A  Linked In: https://www.lin...  Reactjs
# ..                                                ...      ...
# 74  Name : Naresh Babu Cherukuri Objective: To tak...  workday
# 75    3.3 years of IT experience as Workday HC...  workday
# 76  Shireesh Balasani                             ...  workday
# 77   Workday Integration Consultant Name         :...  workday
# 78  Venkateswarlu.B        Workday Consultant     ...  workday
#
# [79 rows x 2 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79 entries, 0 to 78
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Resumes   79 non-null     object
#  1   Catagory  79 non-null     object
# dtypes: object(2)
# memory usage: 1.4+ KB

# %%
data.Catagory.value_counts()
# Out:
# Reactjs          24
# workday          21
# Peoplesoft       20
# SQL_Developer    14
# Name: Catagory, dtype: int64

# %%
data.Catagory.value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
import spacy
import nltk

# %%
import re
import string

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
def clean_text(text):
    '''Make text lowercase, remove text in square brackets,remove links,remove punctuation
    and remove words containing numbers.'''
    text = text.lower()
    text = re.sub('https?://\S+|www\.\S+', '', text)
    text = re.sub('!', '',text)
    text = re.sub('\[.*?\]', '', text)
    text = re.sub('⇨', '',text)
    text = re.sub(':', '',text)
    text = re.sub('•', '',text)
    text = re.sub('<.*?>+', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\n', '', text)
    text = re.sub('\w*\d\w*', '', text)
    text = re.sub('[^a-zA-Z0-9]'," ",text)
    text = re.sub('\s+',' ',text)
    return text

# %%
data['Clean_Resumes'] = data['Resumes'].apply(lambda x: clean_text(x))
data
# Out:
#                                               Resumes Catagory  \
# 0   Name: Ravali P                                ...  Reactjs
# 1   SUSOVAN  BAG    Seeking  a  challenging  posit...  Reactjs
# 2   Kanumuru Deepak Reddy   CAREER OBJECTIVE: To s...  Reactjs
# 3   HARIPRIYA BATTINA  Experience as UI Developer ...  Reactjs
# 4   KAMALAKAR REDDY. A  Linked In: https://www.lin...  Reactjs
# ..                                                ...      ...
# 74  Name : Naresh Babu Cherukuri Objective: To tak...  workday
# 75    3.3 years of IT experience as Workday HC...  workday
# 76  Shireesh Balasani                             ...  workday
# 77   Workday Integration Consultant Name         :...  workday
# 78  Venkateswarlu.B        Workday Consultant     ...  workday
#
#                                         Clean_Resumes
# 0   name ravali p curriculum vitae specialization ...
# 1   susovan bag seeking a challenging position in ...
# 2   kanumuru deepak reddy career objective to secu...
# 3   haripriya battina experience as ui developer i...
# 4   kamalakar reddy a linked in professional summa...
# ..                                                ...
# 74  name naresh babu cherukuri objective to take u...
# 75   years of it experience as workday hcm technic...
# 76  shireesh balasani hcm consultant profile summa...
# 77   workday integration consultant name sri krish...
# 78  venkateswarlub workday consultant having years...
#
# [79 rows x 3 columns]

# %%
 nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Dell\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
my_stop_words=stopwords.words('english')

# %%
def remove_stopwords(text):
    return " ".join([word for word in text.split() if word not in my_stop_words])

# %%
data['Clean_Resumes'] = data['Clean_Resumes'].apply(lambda x: remove_stopwords(x))
data
# Out:
#                                               Resumes Catagory  \
# 0   Name: Ravali P                                ...  Reactjs
# 1   SUSOVAN  BAG    Seeking  a  challenging  posit...  Reactjs
# 2   Kanumuru Deepak Reddy   CAREER OBJECTIVE: To s...  Reactjs
# 3   HARIPRIYA BATTINA  Experience as UI Developer ...  Reactjs
# 4   KAMALAKAR REDDY. A  Linked In: https://www.lin...  Reactjs
# ..                                                ...      ...
# 74  Name : Naresh Babu Cherukuri Objective: To tak...  workday
# 75    3.3 years of IT experience as Workday HC...  workday
# 76  Shireesh Balasani                             ...  workday
# 77   Workday Integration Consultant Name         :...  workday
# 78  Venkateswarlu.B        Workday Consultant     ...  workday
#
#                                         Clean_Resumes
# 0   name ravali p curriculum vitae specialization ...
# 1   susovan bag seeking challenging position field...
# 2   kanumuru deepak reddy career objective secure ...
# 3   haripriya battina experience ui developer reac...
# 4   kamalakar reddy linked professional summary ye...
# ..                                                ...
# 74  name naresh babu cherukuri objective take resp...
# 75  years experience workday hcm technical consult...
# 76  shireesh balasani hcm consultant profile summa...
# 77  workday integration consultant name sri krishn...
# 78  venkateswarlub workday consultant years experi...
#
# [79 rows x 3 columns]

# %%
from nltk.stem import WordNetLemmatizer

# %%
from nltk.tokenize import word_tokenize

# %%
word_lemmatizer = WordNetLemmatizer()

# %%
data['lemmatized_text'] = data['Clean_Resumes'].apply(lambda x: " ".join([word_lemmatizer.lemmatize(i) for i in word_tokenize(x)]))
data
# Out:
#                                               Resumes Catagory  \
# 0   Name: Ravali P                                ...  Reactjs
# 1   SUSOVAN  BAG    Seeking  a  challenging  posit...  Reactjs
# 2   Kanumuru Deepak Reddy   CAREER OBJECTIVE: To s...  Reactjs
# 3   HARIPRIYA BATTINA  Experience as UI Developer ...  Reactjs
# 4   KAMALAKAR REDDY. A  Linked In: https://www.lin...  Reactjs
# ..                                                ...      ...
# 74  Name : Naresh Babu Cherukuri Objective: To tak...  workday
# 75    3.3 years of IT experience as Workday HC...  workday
# 76  Shireesh Balasani                             ...  workday
# 77   Workday Integration Consultant Name         :...  workday
# 78  Venkateswarlu.B        Workday Consultant     ...  workday
#
#                                         Clean_Resumes  \
# 0   name ravali p curriculum vitae specialization ...
# 1   susovan bag seeking challenging position field...
# 2   kanumuru deepak reddy career objective secure ...
# 3   haripriya battina experience ui developer reac...
# 4   kamalakar reddy linked professional summary ye...
# ..                                                ...
# 74  name naresh babu cherukuri objective take resp...
# 75  years experience workday hcm technical consult...
# 76  shireesh balasani hcm consultant profile summa...
# 77  workday integration consultant name sri krishn...
# 78  venkateswarlub workday consultant years experi...
#
#                                       lemmatized_text
# 0   name ravali p curriculum vitae specialization ...
# 1   susovan bag seeking challenging position field...
# 2   kanumuru deepak reddy career objective secure ...
# 3   haripriya battina experience ui developer reac...
# 4   kamalakar reddy linked professional summary ye...
# ..                                                ...
# 74  name naresh babu cherukuri objective take resp...
# 75  year experience workday hcm technical consulta...
# 76  shireesh balasani hcm consultant profile summa...
# 77  workday integration consultant name sri krishn...
# 78  venkateswarlub workday consultant year experie...
#
# [79 rows x 4 columns]

# %%
def lower(text):
    text = text.lower()
    return text

# %%
data["lemmatized_text"] = data["lemmatized_text"].apply(lambda x: lower(x))

# %%
data
# Out:
#                                               Resumes Catagory  \
# 0   Name: Ravali P                                ...  Reactjs
# 1   SUSOVAN  BAG    Seeking  a  challenging  posit...  Reactjs
# 2   Kanumuru Deepak Reddy   CAREER OBJECTIVE: To s...  Reactjs
# 3   HARIPRIYA BATTINA  Experience as UI Developer ...  Reactjs
# 4   KAMALAKAR REDDY. A  Linked In: https://www.lin...  Reactjs
# ..                                                ...      ...
# 74  Name : Naresh Babu Cherukuri Objective: To tak...  workday
# 75    3.3 years of IT experience as Workday HC...  workday
# 76  Shireesh Balasani                             ...  workday
# 77   Workday Integration Consultant Name         :...  workday
# 78  Venkateswarlu.B        Workday Consultant     ...  workday
#
#                                         Clean_Resumes  \
# 0   name ravali p curriculum vitae specialization ...
# 1   susovan bag seeking challenging position field...
# 2   kanumuru deepak reddy career objective secure ...
# 3   haripriya battina experience ui developer reac...
# 4   kamalakar reddy linked professional summary ye...
# ..                                                ...
# 74  name naresh babu cherukuri objective take resp...
# 75  years experience workday hcm technical consult...
# 76  shireesh balasani hcm consultant profile summa...
# 77  workday integration consultant name sri krishn...
# 78  venkateswarlub workday consultant years experi...
#
#                                       lemmatized_text
# 0   name ravali p curriculum vitae specialization ...
# 1   susovan bag seeking challenging position field...
# 2   kanumuru deepak reddy career objective secure ...
# 3   haripriya battina experience ui developer reac...
# 4   kamalakar reddy linked professional summary ye...
# ..                                                ...
# 74  name naresh babu cherukuri objective take resp...
# 75  year experience workday hcm technical consulta...
# 76  shireesh balasani hcm consultant profile summa...
# 77  workday integration consultant name sri krishn...
# 78  venkateswarlub workday consultant year experie...
#
# [79 rows x 4 columns]

# %%
nltk.word_tokenize("rohit is a good guy")
# Out:
# ['rohit', 'is', 'a', 'good', 'guy']

# %%
Sentences = data['lemmatized_text'].values
cleanedSentences = ""
for i in range(0,79):
    cleanedSentences += Sentences[i]
    requiredWords = nltk.word_tokenize(cleanedSentences)

# %%
len(cleanedSentences)
# Out:
# 320302

# %%
len(requiredWords)
# Out:
# 40112

# %%
wordfreqdist = nltk.FreqDist(requiredWords)
mostcommon = wordfreqdist.most_common(50)
print(mostcommon)
# Out:
# [('experience', 600), ('application', 529), ('server', 500), ('report', 471), ('peoplesoft', 438), ('workday', 423), ('using', 391), ('integration', 368), ('project', 360), ('data', 331), ('database', 300), ('process', 289), ('system', 280), ('business', 271), ('web', 240), ('tool', 239), ('sql', 232), ('client', 220), ('worked', 220), ('role', 210), ('knowledge', 208), ('service', 204), ('environment', 201), ('requirement', 199), ('involved', 188), ('team', 185), ('skill', 183), ('support', 178), ('like', 178), ('hcm', 173), ('technology', 171), ('good', 169), ('creating', 163), ('development', 162), ('working', 161), ('design', 160), ('people', 160), ('technical', 153), ('responsibility', 152), ('user', 152), ('testing', 150), ('created', 149), ('developer', 146), ('various', 146), ('change', 145), ('domain', 144), ('issue', 139), ('eib', 137), ('security', 134), ('management', 132)]

# %%
from wordcloud import WordCloud

# %%
wc = WordCloud().generate(cleanedSentences)
plt.figure(figsize=(15,15))
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
reactjs_sentences = data[data["Catagory"]=="Reactjs"]["lemmatized_text"].values
cleanedSentences = ""
for i in range(0,23):
    cleanedSentences += reactjs_sentences[i]
    requiredWords = nltk.word_tokenize(cleanedSentences)
    
wordfreqdist = nltk.FreqDist(requiredWords)
mostcommon = wordfreqdist.most_common(50)
print(mostcommon)

wc = WordCloud().generate(cleanedSentences)
plt.figure(figsize=(15,15))
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.show()
# Out:
# [('react', 115), ('j', 101), ('experience', 97), ('project', 92), ('using', 84), ('web', 72), ('application', 71), ('technology', 66), ('developer', 65), ('javascript', 64), ('knowledge', 61), ('skill', 57), ('e', 56), ('html', 51), ('n', 49), ('design', 49), ('good', 47), ('ui', 47), ('team', 44), ('used', 43), ('work', 42), ('bootstrap', 42), ('system', 40), ('development', 39), ('component', 39), ('working', 38), ('service', 35), ('reactjs', 34), ('responsibility', 33), ('year', 32), ('role', 32), ('cs', 31), ('website', 28), ('software', 27), ('designing', 26), ('responsible', 26), ('professional', 25), ('code', 25), ('page', 25), ('developing', 24), ('engineering', 24), ('jquery', 24), ('technical', 23), ('management', 23), ('redux', 23), ('testing', 22), ('date', 22), ('college', 21), ('client', 21), ('worked', 21)]

# %%
workday_sentences = data[data["Catagory"]=="workday"]["lemmatized_text"].values
cleanedSentences = ""
for i in range(21):
    cleanedSentences += workday_sentences[i]
    requiredWords = nltk.word_tokenize(cleanedSentences)
    
wordfreqdist = nltk.FreqDist(requiredWords)
mostcommon = wordfreqdist.most_common(50)
print(mostcommon)

wc = WordCloud().generate(cleanedSentences)
plt.figure(figsize=(15,15))
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.show()
# Out:
# [('workday', 423), ('integration', 291), ('report', 277), ('business', 186), ('experience', 168), ('using', 147), ('eib', 137), ('process', 124), ('system', 119), ('core', 113), ('hcm', 112), ('worked', 110), ('connector', 109), ('requirement', 107), ('studio', 107), ('field', 101), ('custom', 98), ('data', 97), ('security', 93), ('client', 89), ('created', 89), ('document', 87), ('support', 82), ('consultant', 80), ('testing', 80), ('service', 79), ('project', 78), ('calculated', 75), ('involved', 72), ('xslt', 72), ('change', 70), ('knowledge', 69), ('like', 68), ('team', 66), ('creating', 66), ('xml', 65), ('role', 64), ('good', 62), ('working', 61), ('design', 60), ('developed', 60), ('compensation', 59), ('technical', 58), ('skill', 57), ('new', 57), ('issue', 57), ('inbound', 56), ('functional', 56), ('tool', 55), ('transformation', 55)]

# %%
workday_sentences = data[data["Catagory"]=="SQL_Developer"]["lemmatized_text"].values
cleanedSentences = ""
for i in range(14):
    cleanedSentences += workday_sentences[i]
    requiredWords = nltk.word_tokenize(cleanedSentences)
    
wordfreqdist = nltk.FreqDist(requiredWords)
mostcommon = wordfreqdist.most_common(50)
print(mostcommon)

wc = WordCloud().generate(cleanedSentences)
plt.figure(figsize=(15,15))
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.show()
# Out:
# [('sql', 182), ('data', 122), ('server', 104), ('experience', 103), ('using', 82), ('report', 79), ('table', 75), ('database', 72), ('query', 62), ('function', 61), ('project', 56), ('procedure', 44), ('business', 43), ('service', 43), ('bi', 42), ('system', 41), ('knowledge', 41), ('developer', 37), ('tool', 37), ('view', 37), ('good', 37), ('role', 37), ('stored', 36), ('index', 36), ('requirement', 36), ('like', 34), ('power', 34), ('user', 33), ('ssis', 32), ('development', 32), ('application', 32), ('creating', 31), ('join', 31), ('client', 31), ('date', 30), ('developed', 30), ('design', 30), ('trigger', 29), ('task', 28), ('package', 27), ('skill', 27), ('technology', 27), ('information', 26), ('technical', 24), ('various', 23), ('professional', 23), ('working', 23), ('etl', 22), ('created', 22), ('m', 21)]

# %%
workday_sentences = data[data["Catagory"]=="Peoplesoft"]["lemmatized_text"].values
cleanedSentences = ""
for i in range(20):
    cleanedSentences += workday_sentences[i]
    requiredWords = nltk.word_tokenize(cleanedSentences)
    
wordfreqdist = nltk.FreqDist(requiredWords)
mostcommon = wordfreqdist.most_common(50)
print(mostcommon)

wc = WordCloud().generate(cleanedSentences)
plt.figure(figsize=(15,15))
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.show()
# Out:
# [('peoplesoft', 410), ('server', 388), ('application', 377), ('experience', 228), ('database', 204), ('process', 151), ('environment', 140), ('tool', 136), ('people', 133), ('project', 130), ('domain', 121), ('web', 113), ('oracle', 111), ('report', 111), ('scheduler', 106), ('data', 93), ('support', 84), ('system', 79), ('production', 78), ('involved', 78), ('client', 77), ('using', 76), ('role', 75), ('migration', 75), ('worked', 75), ('issue', 72), ('window', 71), ('change', 68), ('fscm', 67), ('update', 65), ('patch', 63), ('hcm', 61), ('various', 61), ('like', 58), ('user', 58), ('integration', 57), ('creating', 56), ('team', 55), ('pum', 55), ('upgrade', 55), ('configuration', 55), ('troubleshooting', 54), ('setup', 54), ('file', 53), ('peopletools', 52), ('development', 52), ('instance', 52), ('applying', 51), ('responsibility', 51), ('tuxedo', 50)]

# %%
categories = np.sort(data['Catagory'].unique())
categories
# Out:
# array(['Peoplesoft', 'Reactjs', 'SQL_Developer', 'workday'], dtype=object)

# %%
data_categories = [data[data['Catagory'] == category].loc[:, ['lemmatized_text', 'Catagory']] for category in categories]
data_categories
# Out:
# [                                      lemmatized_text    Catagory
#  24  anubhav kumar singh core competency scripting ...  Peoplesoft
#  25  classification internal classification interna...  Peoplesoft
#  26  sirazuddin bangalore india sirazuddin bangalor...  Peoplesoft
#  27  peoplesoft admin varkala vikas career objectiv...  Peoplesoft
#  28  peoplesoft administration vivekanand sayana ca...  Peoplesoft
#  29  hari narayana professional summary year experi...  Peoplesoft
#  30  murali professional summary year experience pe...  Peoplesoft
#  31  priyabrata hota career objective pursuing peop...  Peoplesoft
#  32  tanna sujatha objective seeking challenging ro...  Peoplesoft
#  33  c n c address manyata tech park nagavara banga...  Peoplesoft
#  34  profile summary year experience implementing u...  Peoplesoft
#  35  peoplesoft database administrator gangareddy p...  Peoplesoft
#  36  priyanka ramadoss mountpleasant coonoor nilgir...  Peoplesoft
#  37  peoplesoft administrator srinivask experience ...  Peoplesoft
#  38  vinod akkala peoplesoft dba admin professional...  Peoplesoft
#  39  peoplesoft adminpeoplesoft dba ganesh alladi c...  Peoplesoft
#  40  arun venu experience summary experience year m...  Peoplesoft
#  41  personal detail name pritam biswas date birth ...  Peoplesoft
#  42  rahul ahuja summary year experience peoplesoft...  Peoplesoft
#  43  r ahmed peoplesoft technical consultant profes...  Peoplesoft,
#                                        lemmatized_text Catagory
#  0   name ravali p curriculum vitae specialization ...  Reactjs
#  1   susovan bag seeking challenging position field...  Reactjs
#  2   kanumuru deepak reddy career objective secure ...  Reactjs
#  3   haripriya battina experience ui developer reac...  Reactjs
#  4   kamalakar reddy linked professional summary ye...  Reactjs
#  5   naveen sadhu title software developer location...  Reactjs
#  6   pragnya pattnaik expertise around year experie...  Reactjs
#  7   sarala madasu sarala madasu geethika prestiger...  Reactjs
#  8   thirupathamma balla summary year experience re...  Reactjs
#  9   uideveloper react j developer name krishna pro...  Reactjs
#  10  uideveloper react j developer name krishna pro...  Reactjs
#  11  kotani durga prasad objective aspirant positio...  Reactjs
#  12  venkatalakshmi pedireddy software developer ex...  Reactjs
#  13  kambala sai surendra summary project basic kno...  Reactjs
#  14  mareedu lokesh babu professional overview arou...  Reactjs
#  15  mareedu lokesh babu professional overview arou...  Reactjs
#  16  md khizaruddin rauf experience currently worki...  Reactjs
#  17  pranish sonone career summary experience year ...  Reactjs
#  18  ranga gaganam professional summary professiona...  Reactjs
#  19  shaik abdul sharuk year experience wipro caree...  Reactjs
#  20  profile searching opportunity bring year exper...  Reactjs
#  21  maryala vinay reddy professional summary year ...  Reactjs
#  22  curriculum vitae anjani priyadarshini sr web d...  Reactjs
#  23  page name prabakaran title ui developer profes...  Reactjs,
#                                        lemmatized_text       Catagory
#  44  anil kumar maddukuri sql msbi developer summar...  SQL_Developer
#  45  aradhana tripathi current location gachibowli ...  SQL_Developer
#  46  buddha vamsi career objective year experience ...  SQL_Developer
#  47  kamballa pradeep synopsis looking forward aspi...  SQL_Developer
#  48  resume name neeraj mishra experience summary y...  SQL_Developer
#  49  sql developer name bandi prem sai career objec...  SQL_Developer
#  50  sql server developer p syam kumar professional...  SQL_Developer
#  51  raju pavana kumari professional summary year p...  SQL_Developer
#  52  resume ramalakshmi k career objective professi...  SQL_Developer
#  53  name ramesh career objective contribute organi...  SQL_Developer
#  54  sql msbi developer sql msbi developer b vinod ...  SQL_Developer
#  55  hyderabad nazeer basha sql power bi developer ...  SQL_Developer
#  56  sql server developer priyanka l professional s...  SQL_Developer
#  57  career objective rewarding opportunity growtho...  SQL_Developer,
#                                        lemmatized_text Catagory
#  58  chinna subbarayudu dob march nationality india...  workday
#  59  name gopi krishna reddy professional summery w...  workday
#  60  g himaja career objective work towards achievi...  workday
#  61  jyoti verma professional summary professional ...  workday
#  62  mooraboyina guravaiah workday integration spec...  workday
#  63  venkata saikrishna workday consultant profssio...  workday
#  64  workday hcm techno functional consultant rahul...  workday
#  65  ramesh workday hcm consultant professional sum...  workday
#  66  srikanth workday hcm consultant seeking suitab...  workday
#  67  workday hcm fcm name kumar s role workday cons...  workday
#  68  vinay kumar v workday functional consultant ex...  workday
#  69  hari krishna summary result oriented professio...  workday
#  70  harikrishna akula summary year experience arou...  workday
#  71  himamendu career objective continue growing kn...  workday
#  72  name j sumanth royal professional summary tota...  workday
#  73  madeeswar profile summary around year experien...  workday
#  74  name naresh babu cherukuri objective take resp...  workday
#  75  year experience workday hcm technical consulta...  workday
#  76  shireesh balasani hcm consultant profile summa...  workday
#  77  workday integration consultant name sri krishn...  workday
#  78  venkateswarlub workday consultant year experie...  workday]

# %%
def wordcloud(df):
    txt = nltk.word_tokenize(data_categories["lemmatized_text"].values)
    wordcloud = WordCloud(
        height=2000,
        width=4000,
        colormap=WORDCLOUD_COLOR_MAP
    ).generate(txt)

    return wordcloud

# %%
data_categories[0]["lemmatized_text"].values
# Out:
# array(['anubhav kumar singh core competency scripting shell scripting application peoplesoft hcm financials operating system linux window webapp server weblogic tuxedo rdbms oracle repository github core competency scripting shell scripting application peoplesoft hcm financials operating system linux window webapp server weblogic tuxedo rdbms oracle repository github work globally competitive environment challenging assignment shall yield twin benefit job satisfaction steadypaced professional growth professional experience current hcl current role system admin offshore skill shell scripting linux peoplesoft administration github managing peoplesoft hcm peoplesoft fscm production environment along support environment installed linux window o involved day day activity project migration database refresh system admin change tax update etc troubleshooting various server like application server web server process scheduler server applying tuxedo weblogic middleware cpu patch various application working shell scripting used integration method exchange file external system installation troubleshooting setup per requirement reviewing vulnerability reported security team renewal ssl weblogic vulnerability remediation whenever vulnerability report rmis team worked pum peoplesoft update manager installation dpk working knowledge ansible docker developing new shell script troubleshooting shell script failure techmahindra roleproject application support automationdevops tool peoplesoft admin skill shell scripting linux peoplesoft administration jenkins ansible project people tool upgrade hcm application upgrade project migration application ntt cloud onpremises aws cloud worked shell scripting various application requirement working ansible jenkins automated startstop various activity application basic knowledge docker applying ssl certificate new released application worked elastic search configuration peoplesoft gained knowledge aws resource strong understanding unix architecturecommand trouble shooting unixlinux platform efficient using configuration management deployment tool like ansible good experience job scheduling via crontab ibm tivoli workload scheduler tws good knowledge automation using shell scripting continuous integration management using jenkins installing configuring jenkins responsible writing ansible playbook perform various task managed administration task installation configuration application troubleshooting performance related issue applying tuxedo weblogic cpu patch various application working vulnerability reported security team reviewing platform certification information product platform database server web application server browser product peopletools server migration aws amazon web service installation peoplesoft server component application server process scheduler server tuxedo web logic server new release peopletools unixlinux server applying latest patch peopletools installing configuring change assistant various upgrade pass creating running peopletools upgrade job peopletools upgrade setting performance monitor creating new app web process scheduler domain post upgrade new linux severs troubleshooting common domain boot problem identifying configuring source target database ca hcm application upgrade working hcm pum image creating change package using pum applying sourcetarget database per requirement creating application upgrade job using change assistant srdt pvt ltd srm group roleproject peoplesoft application database admin skill peoplesoft administration weblogic tuxedo app designer pum peopletools upgrade peoplesoft campus application upgrade maintaining production environment supporting environment installed window server oracle posse knowledge experience peoplesoft architecture administering peoplesoft server component application server process scheduler server tuxedo web logic server pia peoplesoft internet architecture integration broker report node application issue technical issue peoplesoft ...
#        'classification internal classification internal murali experience summary year experience working peoplesoft administration performing various infrastructure related activity peoplesoft environment installed configured peoplesoft web server application server database server process scheduler server window unix linux platform creating domain web server application server process scheduler server applied patch manually applied maintenance pack change assistant tool experience dpks installation applying tax update fix using pum migrating project one environment another environment using application designer also capi stat tool performed single sign ssoimplementation experience running compare report pre post migration experience setting client workstation developer tester involved configuration integration broker setting module sending message involved production support client involved running audit report dddaudit sysaudit integrity check experience configuration setup ren server configured maintained report node setting checked clear cache server involved troubleshooting server like application server web server process scheduler server worked peopletools upgrade installing configuring elastic search career profile date organization role mar may l n infotech peoplesoft administrator client sembcorp brazil description project involved active production support field hrms additionally also involved maintenance enhancement system responsibility installation setup people soft hcm elm oracle creating database user assigning role privilege user maintaining various people soft instance debugging resolving issue related application serverweb serverprocess scheduler weeklymonthly database maintains performed people tool upgrade performing post refresh activity date organization role nov mar regency technology peoplesoft administrator client wipro ind platform people tool people soft hcm description project involved active production support field hrms additionally also involved maintenance enhancement system responsibility installation setup people soft hcm oracle creating database user assigning role privilege user maintaining various people soft instance debugging resolving issue related application serverweb serverprocess scheduler weeklymonthly database maintains creating modifying data mover script migrating project using capi applying patch setting peoplesoft reporting environment reporting interacting client various production related issue applying tax update using pum performing post refresh activity date organization role nov nov dxc technology formerly known csc peoplesoft administrator project title people soft hcm production support enhancement client asg usa platform people tool people soft hcm aix description project involved active production support field hrms additionally also involved maintenance enhancement system responsibility installation setup people soft hcm creating database user assigning role privilege user maintaining various people soft instance debugging resolving issue related application serverweb serverprocess scheduler weeklymonthly database maintains creating modifying data mover script migrating project using statcapi applying patch setting peoplesoft reporting environment reporting interacting client various production related issue applying tax update using pum performing post refresh activity technology operating system window platform linux erp tool peoplesoft hrms peopletools putty sql toad beyond compare rdbms oracle scheduling tool autosys version control tool capi stat language c c sql personal detail date birth nationality indian date place hyderabad',
#        'sirazuddin bangalore india sirazuddin bangalore india profile summary overall year experience peoplesoft administrator installed peopletools scratch including product experience peopletools hrmsfscm deterministic approach towards problem solving troubleshooting proficient integration broker upgraded fscm hcm application peopletools peopletools education graduated btech electronics communication engg mvgr college engineering vizianagaramjntuk aggregate achieved mark standard scored standard achievement awarded bravo pat back techahindra awarded associate month award innovator month time awarded spot pat back capgemini work experience capgemini may till production support finance environment respective non production environment project experience project name axa role consultant environment window server cognizant technol ogy sol ut ion augus april voya financial insurance u client project deal support managing finance application project experience project name voya financials role associate environment window server tech mahindra limit ed july augus peoplesoft implemented hr fin application peoplesoft implementation project includes peoplesoft application interface thirdparty application interface live production peoplesoft environment sdlc project experience project name role environment cio common software engineer solaris window server responsibility provided administrative support peoplesoft tool version application hrms financialsscm module window unix o creation index table application designer peoplesoft database setup troubleshooting issue daily peoplesoft admin activity configured peoplesoft application server process scheduler web server domain setup master scheduler installing oracle tuxedo weblogic java application disk fscm hcm oracle database unix window server scratch installed peopletools hcm fscm demo database upgraded fscm application peopletools peopletools applied patch fscm configured report node bouncing app web process scheduler clearing cache performed prerefresh post refresh activity database cloning activity recompilation cobol source code worked project migration using application designer change assistant applied image fscm using pum change assistant good handson experience application designer data mover change assistant well aware pia peoplesoft internet architecture configuring integration broker report node creating udm file transfer interface monitoring deploying gnupg key certificate server installed configured elastic search tool used peopletools application designer data mover toad sqldeveloper microsoft sql management studio oracle oracle microsoft sql server filezilla winscp pcomm tws service silva training certification oracle cloud infrastructure architect associate oracle cloud infrastructure architect professional',
#        'peoplesoft admin varkala vikas career objective total year experience peoplesoft admin peoplesoft dba hope enhance skill set adding value business enable implementation solution aid company objective understanding anticipating need interest motivation client deliver time budget quality delivering value improving agility quality reliability professional summary year experience peoplesoft implementation support people tool upgrade configuration migration maintenance administration application server domain process scheduler server web server domain pum elastic search involved various tool application upgrade experience driving infrastructure hardware upgrade disaster recovery activity configured http secure web server ssl administration monitor system developing maintaining monitoring shell script experience oracle database administration experience health check peoplesoft environment experience peoplesoft database refreshes production development testing environment experience performance tuning application server web server experience window administration implemented peoplesoft internet architecture pia demo test development production instance extensively involved resolving performance issue experience peoplesoft installation peopletools hcm weblogic tuxedo people book window depth experience peoplesoft update manager pum applying peopletools patch application bundle peopletools hrms fscm application depth experience integration broker setup experience secure socket layer ssl implementation peoplesoft proficiency creation configuration administration application server domain process scheduler domain web server domain experience reconfiguration application server domain process scheduler server domain web server domain experience project migration using application designer data migration using data mover experience generating precompare report post compare report various environment experience setting client work station developer tester experience resolving developer issue like resetting password locking unlocking user account maintain workflow peoplesoft user worked applying patch bundle tax update using change assistant peoplesoft update manager pum installing configuring change assistant apply bundle taxupdates involved setup configuration integration broker financials hcm application maintaining integrity internal consistency database using dddaudit sysaudit alteraudit report periodically experience clearing cache server application server domain web server domain process scheduler server regular basis monitor log file find bottleneck status server maintaining troubleshooting various server like application server domain process scheduler domain web server domain regularly involved database cloning refreshing peoplesoft instance experience installing cobol software compilation experience tuning application server domain process scheduler domain web server domain depth experience peoplesoft database performance tuning experience data guard dr support experience database patching experience peoplesoft database refreshes using rman good team player proven individual contributor area technical skill technology tool erp tool people tool assistant integration broker application designer configuration manager peoplesoft update manager pum s data mover peoplesoft hrmsfscmcrm application server tuxedo web server operating system window server oracle enterprise linux hpux database oracle educational qualification bsc osmania university professional experience worked peoplesoft administrator peoplesoft dba progile infotech pvt ltd july till date project experience achievement client hartford insurance group hartford ct project install configure production support peoplesoft application database environment people tool oracle tuxedo oracle weblogic window server oracle enterprise linux role peoplesoft adminpeoplesoft dba duration july till date role responsibility monitoring daytoday working system build verification test  ...
#        'peoplesoft administration vivekanand sayana career objective valid expertise year peoplesoft hope enhance skill set adding value business enable implementation solution aid company objective understanding anticipating need interest motivation client deliver time budget quality delivering value improving agility quality reliability professional summary year experience peoplesoft implementation support configuration migration maintenance administration application server domain process scheduler server web server domain peopletools upgrade application update pum s elastic search experience integration activity various peoplesoft financials hrms epm fscm environment extensively involved resolving performance issue experience driving infrastructure hardware upgrade disaster recovery activity experience health check peoplesoft environment experience peoplesoft database refreshes production development testing environment experience performance tuning application server web server performed full life cycle implementation peoplesoft implemented peoplesoft internet architecture pia demo test development production instance experience peoplesoft implementation peopletools fscm web logic tuxedo oracle oracle enterprise linux window experience peoplesoft installation peopletools hcm weblogic tuxedo people book oracle enterprise linux window experience peoplesoft installation peopletools hcm weblogic tuxedo people book window oracle enterprise linux experience peoplesoft installation peopletools fscm weblogic tuxedo people book window oracle enterprise linux experience peoplesoft installation peopletools hcm tuxedo oracle people book window server oracle enterprise linux depth experience peoplesoft update manager pum applying peopletools patch application bundle peopletools hrms fscm application using dpk deploy pum latest image dpk install middle tier app tier peopletools depth experience integration broker troubleshooting proficiency creation configuration administration application server domain process scheduler domain web server domain experience reconfiguration application server domain process scheduler server domain web server domain experience project migration using application designer data migration using data mover experience generating precompare report post compare report various environment experience setting client work station developer tester experience resolving developer issue like resetting password locking unlocking user account maintain workflow peoplesoft user worked applying patch bundle tax update using change assistant peoplesoft update manager pum installing configuring change assistant apply bundle taxupdates involved setup configuration integration broker financials hcm application maintaining integrity internal consistency database using dddaudit sysaudit alteraudit report periodically experience load balancing application server domain process scheduler server experience clearing cache server application server domain web server domain process scheduler server regular basis monitor log file find bottleneck status server experience troubleshooting data mover installing peoplesoft maintaining troubleshooting various server like application server domain process scheduler domain web server domain experience tuning application server domain process scheduler domain web server domain strong communication collaboration team building interpersonal skill good team player proven individual contributor area technical skill technology tool erp tool people tool assistant integration broker application designer configuration manager peoplesoft update manager pum s data mover application peoplesoft hrmsfscmcrm application server tuxedo web server web logic operating system window server redhat enterprise linux oracle enterprise linux database oracle educational qualification mba hr marketing kbn college nagarjuna university vijayawada bsc bachelor science srr cvr college nagarjuna university vijayawada professio ...
#        'hari narayana professional summary year experience peoplesoft application enhancement implementation data conversion support upgrade project well experienced people tool functional knowledge hcm fscm application skill people tool application designer application engine people code application package peoplesoft application fscm hcm application fscm module procurement po ap ar billing gl hcm module recruiting performance management waf benefit interface component interface file layout language c c database oracle sql server operating system window unix education bachelor technology btech jntuk currently working people soft consultant randstad hyderabad relevant experience peoplesoft consultant randstad hyderabad andhra pradesh india june till date project randstad enhancement client randstad staffing responsibility analyze requirement document understand customer business requirement provide technical approach fdd assign customize system application designed many object scratch write people code implement business logic design custom application engine program process data design application engine program send notification responsible prepare unit test case technical design document responsible support sit uat environment people tool application designer application engine people code component interface application package peoplesoft hcm oracle window technical associate verizon hyderabad andhra pradesh india dec project verizon wireless development client verizon responsibility analyze requirement document understand customer business requirement provide technical approach fdd assign customize system application designed many object scratch write people code implement business logic design custom application engine program process data design application engine program send notification implemented component interface program load data people soft used file layout inbound program responsible prepare unit test case technical design document responsible support sit uat environment people tool application designer application engine people code component interface application package peoplesoft fscm oracle window software engineer hsbc hyderabad india aug nov project hsbc upgrade project client hsbc bank responsibility analysis understand source target system business process compare object source target identify change retrofit object based compare report unit testing prepare unit test case retrofit design development new modification required customer prepared technical design document retrofit enhancement add new text catalogue various language responsible overseeing quality procedure related project responsible move object development sit environment environment people tool application designer application engine people code peoplesoft hcm window unix page page page page ciber inc right reserved ciber inc right reserved',
#        'murali professional summary year experience peoplesoft application enhancement support upgrade project well experienced people tool functional knowledge hcm fscm application skill people tool application designer application engine people code application package peoplesoft application fscm hcm application fscm module procurement po ap ar billing gl hcm module recruiting performance management waf benefit interface component interface file layout language c c database oracle sql server operating system window unix education master computer application vinayaka mission university chennai tamilnadu india program relevant experience senior consultant randstad hyderabad andhra pradesh india june till date project randstad enhancement client randstad staffing responsibility analyze requirement document understand customer business requirement provide technical approach fdd assign customize system application designed many object scratch write people code implement business logic design custom application engine program process data design application engine program send notification responsible prepare unit test case technical design document responsible support sit uat environment people tool application designer application engine people code component interface application package peoplesoft hcm oracle window sr technical associate verizon hyderabad andhra pradesh india dec project verizon wireless development client verizon responsibility analyze requirement document understand customer business requirement provide technical approach fdd assign customize system application designed many object scratch write people code implement business logic design custom application engine program process data design application engine program send notification implemented component interface program load data people soft used file layout inbound program responsible prepare unit test case technical design document responsible support sit uat environment people tool application designer application engine people code component interface application package peoplesoft fscm oracle window senior software engineer hsbc hyderabad india aug nov project hsbc upgrade project client hsbc bank responsibility analysis understand source target system business process compare object source target identify change retrofit object based compare report unit testing prepare unit test case retrofit design development new modification required customer prepared technical design document retrofit enhancement add new text catalogue various language responsible overseeing quality procedure related project responsible move object development sit environment environment people tool application designer application engine people code peoplesoft hcm window unix page page page page ciber inc right reserved ciber inc right reserved',
#        'priyabrata hota career objective pursuing peoplesoft executive role overall experience year financial supply chain management process include modification testing supporting peoplesoft fscm module professional skill functional purchasing inventory billing sound knowledge account payable sound knowledge peoplesoft security technical p query basic knowledge peoplesoft security application designer peoplecode sql tool people tool oracle sql developer database oracle professional summary project module account payable client account team aptara role developer technology used crystal report people tool application designer reporting tool application designer using tool created page contains run control record page add component register component reflected piapure internet architecture people tool created permission list help people tool permission list separate role selected user access page also created process run crystal tool output visible process monitor reporting tool created p query help reporting tool main report sub report crystal report crystal report tool used p query formula field running total field get required output project module purchasing client admin team role developer technology used people tool client requirement requisition purpose create new origin admin requisition raise origin admin purpose get requisition approval flow admin created origin admin add origin route control profile help people tool route control profile added approver user id get work done tracking defect closure defect verification status meeting client creating peoplesoft user id per user requirement creating origin route control profile role requisition handling requisition purchase order receipt inventory related issue creating billing specialist etc per requirement user also resolve bug eg invoice get printed etc handling journal error issue eg might combo error amount difference open period error zero line error functional summary oracle peoplesoft application finance module handled resource management fscm purchasing inventory billing sound knowledge account payable sound knowledge peoplesoft security technical summary primary skill p query application designer field record page component menu sql secondary skill peoplecode tool people tool oracle sql developer database oracle education btech electrical electronics engineering indus college engineering biju patnaik university technology orissa personal vitae date birth jan language english hindi odia nationality indian gender male declaration hereby declare information given true correct knowledge belief date priyabrata hota',
#        'tanna sujatha objective seeking challenging role area work organization utilize functional knowledge provide best solution business professional summary functional expertise peoplesoft finance module purchase account payable experienced working reporting tool like psquery endend functional knowledge ap po module handled various change request user synopsis energetic result oriented professional year experience extended expertise peoplesoft financials area design maintenance production support deep understanding technology focus delivering business solution presently working sr system engineer excellent decisionmaking skill positive approach dedicated highly ambitious achieve personal goal well organizational goal ability build new territory expand opportunity towards achievement stated target education btech kaushik college engineering visakhapatnam academic percentage puc narayana junior college visakhapatnam academic percentage ssc zp high school burja academic percentage software proficiency peoplesoft functional purchase account payable vendor management database oracle sql developer reporting tool p query work history company datum technology mar designation sr system engineer project handled project jul present project name datum peoplesoft fscm maintenance support client datum role sr system engineer duration jul present team size description maintenance production batch support project maintenance involves working ticket need customization setup enhancement creating modifying peoplesoft object production support involves monitoring batch job scheduled role responsibility monitoring batch job resolving job failure time unit testing documentation per organizational requirement documentation process flow per business requirement involved interaction user requirementchange gathering uats etc handling various request user personal detail date birth july language english telugu gender female marital status married nationality indian present address pocharam hyderabad telangana india hereby declare information furnished true best knowledge sujatha tanna',
#        'c n c address manyata tech park nagavara bangalore linin k l l peoplesoft finance fscm ariba java full stack development sql power bi n e r e learning new technology planting hybrid specie cooking travelling singing r e n g h time management responsible deliverable leadership quality l n g u g e japanese french started learning sri subha santosh kumar josyula c e c n u l n p r f e n l u r year experience assistance development project like ariba peoplesoft finance successfully completed tool patch tool upgrade project refuse validation main point contact non regression testing user acceptance testing responsible find solution make customer satisfaction w r k e x p e r e n c e associate consultant capgemini axa june till date working module like account payable account receivable general ledger expense user profile self service us security along application designer sql server organised customer information account data business planning customer service purpose received positive customer survey result worked people code packaging activity successfully monitored process monitoring failed job collectively worked team maintain sla developed implemented many java script make change per client requirement e u c n bachelor technology electronics communication vishnu institute technology jntuk average w r n c e r f c n basic certified power bi desktop manager coursera agile software development rising star award capgemini best team award peoplesoft finance team java developer microsoft office specialist japanese language basic certification',
#        'profile summary year experience implementing upgrading supporting peoplesoft database administration including human capital management hcm financials campus solution portal ihub expertise installation configuration setup security management peoplesoft internet architecture pia environment indepth experience analysis planning development implementation stage including load testing quality assurance tuning gained extensive exposure deploying peoplesoft environment experienced troubleshooting peoplesoft component skilled capability analyse interpret unique problem combination training experience logical thinking find right solution core competency peoplesoft implementation troubleshooting peoplesoft performance issue project data migration installation configuration peoplesoft component pum dpk install configure upgrade people tool expertise applying patch update via change assistant tool including tax update elastic search install configure peoplesoft refreshes cloning integration broker setup configuration maintaining workflow peoplesoft user monitoring log file search bottleneck server peoplesoft security resetting password lockingunlocking user profile installing middle tier component oracle quarterly security patch configuring change assistant apply fix patch set peoplesoft cloud infrastructureiaas cloud managerlift shift application cloud work experience organization idc technology sol pvt ltd project multiple client texas department transportationtxdot duration aug till date role peoplesoft dba environment people tool hrms fscm tuxedo weblogic oracle responsibility performing project migration using phire performing oracle security patchingjava wls installed middle tier component tuxedo weblogic jdk java performing peoplesoft database refresh troubleshooting application server process scheduler server report posting performance issue resolved developer issue like resetting password lockingunlocking user examining clearing cache server like application server monthly maintenance process prepared maintained documentation non prod prod refresh organization safalta infotech pvt ltd nov aug project multiple client university texas system ut papa jones duration role peoplesoft dba environment people tool hrms fscm campus solution portal solution tuxedo weblogic responsibility implemented complete peoplesoft life cycle scratch production golive activity executing peoplesoft internet architecture pia demo development support test production instance psadmin utility administer create app server process scheduler server webserver domain installed middle tier component tuxedo weblogic jdk java performed peoplesoft database refresh peoplesoft cloning activity performing project migration using application designer maintaining workflow peoplesoft user monitoring log file search bottleneck server troubleshooting application server process scheduler server report posting performance issue resolved developer issue like resetting password lockingunlocking user provided resolution client analysed production issue examining clearing cache server like application server monthly maintenance process setup integration broker defining gateway creating configuring application node prepared maintained documentation entire configuration running audit report review sys ddd audit data inconsistency performed data migration performing production move performed server load balancing webserver application tier hand experience setting pumdpk image creating change package application fix bug configured change assistant download update fix apply target environment install configure elastic search performed executed oracle cpu quarterly security patch nprod prod environment perfumed instance verification test patching database refresh cloning activity performed people tool upgrade release install configure dpk image extracting peoplesoft change package bug fix tax update troubleshooting report posting issue ib related issue production nprod environm ...
#        'peoplesoft database administrator gangareddy professional objective work professional challenging environment best utilizing talent keeping abreast latest technical advancement field peoplesoft application dba derive utmost job satisfaction knowledge field become successful oracle peoplesoft application dba activity professional summary year experience peoplesoft application admindba experience creating configuring application server domain created multiple server domain separate host system access one database effective strategy performance tuning experience application server administration ensured system availability implementing failover spreading multiple domain across multiple host peoplesoft server administration expertise installation configuration setup management database peoplesoft internet architecture pia environment related processing object extensive experience applying tax update patch fix bundle maintenance pack experienced peoplesoft application administrator including performance problem sqr report app engine tuning sql index creation migration change management extensive experience refreshing development qa production database migrating change qa production evaluating required patch applying peoplesoft system timely basis experience report management monitoring batch environment peoplesoft server administration expertise installation configuration setup management database peoplesoft internet architecture pia environment related processing object experience monitoring scheduling job experience security administration experience creating managing batch environment taking scheduled backup per backup strategy using rman configured maintaining rman take backup oracle sql server database experienced taking regular offline online logical backup experience backup like logical backup exp imp datapump successfully installed configured oracle s peoplesoft environment involved configuration ssl certificate weblogic successfully installed applied pum peoplesoft update manager technical skill erp package peoplesoft hrmsfscmcrmcshcmportal people tool version peopletools application server bea tuxedo tuxedo web server bea weblogic weblogic database oracle mssql server operating system rhel oel oel window professional experience working emergtech business solution india pvt ltd may till date client amerit fleet solution duration sep database mssql server role peoplesoft administratordba environment peoplesoft hcm fscm crm elm c portal pt oracle rhel window server project kc managed service responsibility successfully installed configured web logic server application server component database server window operating system successfully installed configured oracle s peoplesoft environment involved installation application database environment involved configuration ssl certificate weblogic working daily production development administration activity perform proactive monitoring involved supporting team member various project successfully applied peoplesoft update managerpum handled application management task like applying patch fix cloning production server testing purpose like applying patch bundle installed peoplesoft database application nt unix operating system installed configured oracle database updated database applying updatesfixespatches backup timely basis kept record updatesfixespatches configured application server web server batch process scheduler server configured window development client connect database development administration purpose professional experience client db duration may database role peoplesoft administratordba environment peoplesoft fscm pt rhel window server project db managed service responsibility configured application server webservers batch process scheduler server extensively used psadmin utility administer create delete application server process scheduler server monitored server client queue status several tuxedo domain changed psappsrvcfgpsprcscfg configuration file perform ...
#        'priyanka ramadoss mountpleasant coonoor nilgiris career objective excel software professional working learning challenging environment utilize skill knowledge diligence dedication ensure maximum contribution growth organization work profile summary adept professional year september present experience peoplesoft admin accenture professional summary peoplesoft administrator september experience peoplesoft administration finance application proficient creating configuring peoplesoft component like web server application server process scheduler active monitoring non production database application knowledgeable peoplesoft migration using application designer data mover taking compare report also moving code dev test production environment usage hp ppm tool well perform peoplesoft migration compare report generation full life cycle installation peoplesoft environment pre post database refresh activity change package creation applying bug fix using change assistant peoplesoft db proficient administration peoplesoft server component like application server process scheduler webserver peoplesoft internet architecture good knowledge basic peoplesoft configuration like integration broker setup pum setup ssl file attachment trouble shooting hand experience peoplesoft security level activity like creating user profile assigning role permission list sso login creation user renewing web certificate performing sox check migration part production release monthly basis conversant usage controlm tool used creating scheduling job experienced setting batch profile setup server level running controlm job testing production environment peoplesoft batch monitoring implementation worked change assistant experience applying people tool patch experience creating change packagees target database ca online experience working unix window worked delphix virtual database non production database refreshes carrying maintenance activity server good communication leadership ability problem solving skill vmware itbm application support associate configuring maintaining infrastructure itbm application window o worked apache tomcat vmware itbm version window server ssl configuration complete batch setup window envrironment handling production non production database itbm tool technology operating system window server solaris server linux red hat version apache tomcat aws service tool compute storage network database monitoring identity access management project management tool odyssey dashboard odyssey jira service transporter database sql developer peoplesoft people tool peoplesoft application fscm version reporting p tool application designer data mover delphix virtual database configuration manager change assistant sqr nvision controlm scheduler hp ppm sql developer centrify putty configuration manager key achievement infrastructure support production environment also provide system contingency plan analyze technical functional aspect supported application troubleshoot problem based requirement detailed analysis reporting project activity experience summary organization accenture solution pvt ltd client credit suisse client description credit suisse group ag global wealth manager investment bank financial service company providing service investment banking provate banking asset management sahred service responsibility environment administration management financial application location bangalore duration september present education course schoolcollege boarduniversity year passing percentage ece sri krishna college engineering technology coimbatore anna university hsc bharathi vidya bhavan erode state board technical education school topper sslc st joseph convent anglo indian girl higher secondary school nilgiris angloindian district third personal profile ootacamund ooty tamil nadu district place birth tamil native english advanced comprehension oral kannada intermediate oral hindi intermediate sanskrit intermediate language reading book yoga gardeni ...
#        'peoplesoft administrator srinivask experience summary year experience peoplesoft administrator ample experience peoplesoft installationsconfigurations security system administration adept implementing supporting peoplesoft database administration dba including human resource management system hrms financial system f thorough knowledge experience administrating peoplesoft server component like peoplesoft application server process scheduler server tuxedo web logic server pia peoplesoft internet architecture application messaging integration broker sql server application issue technical issue etc installing administering peoplesoft software configuring workstation application server process scheduler tuxedo web server pia report repository report node peoplesoft application installed elastic search configured peoplesoft solid understanding peoplesoft technical architecture tool proficient performing administer patch update upgrade develop implement plan data migration installing configuring pum applied tax update using pum aided maintenance peoplesoft pure internet architecture including web logic tuxedo report process server posse thorough knowledge peoplesoft architecture peoplesoft system administration design implementing suite corporation specific need cobol installation troubleshooting compiling cobol issue performed integration broker setup two module worked instance verification test data refresh production ensuring data integrity using tool dddaudit sysaudit development phase helped create implement security server administration procedure sql oracle database developed functional technical specification performed administrative duty worked autosys scheduling process monthly maintenance activity like cleaning application web process scheduler server experienced people tool upgrade knowledge application upgrade experienced monitoring peoplesoft job tivoli job scheduling console tool creating new job scheduling job per requirement troubleshooting issue training junior employee peoplesoft administration related task handled project migration security request per work order sent ticketing system performed refreshing source target database peoplesoft experience online offline cloning server adaptive cloud strategy based aws experience aws cloud platform feature includes vpc eb cloud watch load balancer iam qualification bachelor technology cse jntu lenora college egg andhrapradesh year technical skill peoplesoft peoplesoft application people tool version application designer application engine people code data mover process scheduler peoplesoft reporting tool pum image sqr p query xml publisher weblogic tuxedo database oracle oracle oracle operating system window unix linux work experience currently working peoplesoft admin tech mahindramahindra satyam till date worked peoplesoft dba hexaware technology june environment unix window server database application level hrms tool version project nissan responsibility involved peopletools upgrade people tool supporting hcm fscm application apps dba basis strong experience peoplesoft pum server installation troubleshooting applying fix patch bundle peoplesoft using peoplesoft pum applied security patch weblogic tuxedo whenever oracle release cpu setup masterslave load balance pubsub service worked intensively performance tuning pia architecture based load testing scaling architecture support expected load created dedicated integration broker gateway message volume high easy maintenance installed elastic search configured peoplesoft deployment peoplesoft dpk experience applying peoplesoft release patch prp peoplesoft image experience applying webserver oracle weblogic patch experiencing applying application server oracle tuxedo patch experience migrating code change testing production environment redesigned configured high availability load balancing existing peoplesoft internet architecture build verification test check proper installation running process report responsible  ...
# ...
#        'arun venu experience summary experience year month multiple peoplesoft upgrade implementation support project fscmhcm global client depth knowledge experience working peopletools application engine peoplecode application package file layout exceltoci psquery reporting sqrs bi publisher worked fscm upgrade includes vanilla compare retrofitting object sit uat go live activity good experience upgrade implementation module good experience phase application development cycle design coding testing maintenance documentation worked creating custom report using bi publisher sqr p query worked testing tool ptfpeoplesoft testing framework excellent capability explore learn understand newer business domain technology good communication skill software proficiency skill app package application engine people code sqr bip p query domain knowledge financial service retail healthcare development tool peoplesoft application designer data management data mover integration tool integration broker database oracle working experience currently working peoplesoft technical consultant since december till date wipro technology educational qualification bca computer application guru gobind singh indraparastha university mtech software engineering bit pilani wipro wase program professional experience project tool upgrade customer credit suisse domain financial service role hcm technical consultant period feb june description credit suisse group ag global investment bank financial service firm founded based switzerland responsibility analysis customizations es ms page fluid implementation converting es page fluid page like name change home mailing address swiss payslip phone number email address emergency contact ethnic group converting ms page fluid data conversion bring attachment previous custom table new fluid delivered table batch catchup analysis check batch process require catchup golive worked cutover security document golive module es ms wa environment peoplesoft hcm people tool project global offboarding automation customer credit suisse domain financial service role hcm technical consultant period july jan description credit suisse group ag global investment bank financial service firm founded based switzerland responsibility created custom ms termination page manager submit resignation behalf direct reportees created checklist automation program complete checklist item per configuration framework avoid manual check item created contract expiry reminder process send reminder short term employee whose contract getting expired day created many bi report generate letter different region created custom stakeholder response page creation cutover document golive provided support warranty period golive module es ms environment peoplesoft hcm people tool project end life ptf customer credit suisse domain financial service role financial technical consultant period april june description credit suisse group ag global investment bank financial service firm founded based switzerland responsibility retrofit object like app package app engine page peoplecode sql worked gl journal entry journal edit posting journal reversal journal worked peoplesoft testing framework regression testing gl module gl environment peoplesoft fscm people tool project lease administration customer credit suisse domain financial service role financial technical consultant period january april description credit suisse group ag global investment bank financial service firm founded based switzerland responsibility created feed process load lease system file received external source worked creationmanaging financial operating lease ran lease process like straightline process depreciation calculate accounting entry depreciation close validated data distln record worked amendment lease module lm environment peoplesoft fscm people tool project labcorp upgrade customer laboratory corporation america holding domain healthcare role financial technical consultant period december novem ...
#        'personal detail name pritam biswas date birth present location pune experience summary year experience development support maintenance upgrade peoplesoft project ibm currently working peoplesoft implementation project accenture exposure working finance module hcm module technical knowledge hand experience people tool version worked peoplesoft hrms application version worked technical aspect creating peoplesoft object like field record page component file layout application engine bi publisher report form etc worked creating sqrs worked creating application engine worked creating bi publisher report worked creating p query handson experience generic event mapping worked peoplesoft job job stream management iw basic idea control schedule monitor job basic idea service jira phire ticketing tool skill technical skill technology peoplesoft erp hrms application v operating system window version till mac o programming language c python beginner peoplecode sqr tool people tool oracle sql developer app designer tectia client servicenow winscp iw control database oracle sql server reporting tool sqr p query bi publisher industry hcm finance soft skill dedicated work eager adopt new skill good communication presentation skill english hindi bengali interested solving analytical problem good team player adopt hazardous situation educational qualification degree institution stream percentage cgpa year passing btech national institute technology durgapur electrical engineering higher secondary burdwan municipal high school pure science includes computer science secondary burdwan municipal high school subject job history ibm india pvt ltd july may accenture india june ti till date professional summary employer client ibm india citigroup finance project peoplesoft production support maintenance tenure october responsibility provide technical support provide analysis peoplesoft related issue coming level support team working supporting application crc etl apss citigl cbsi fr support user directly issue come host team meeting update manage status issue create calendar autosys job batch file run support green zone production checkout make dailyweekly report various application analyze solve problem ticket incident handle servicenow tool create modify incident ticket change request worked full ndm certificate update ndm testing got successful signoff client worked dsmt load activity checkout team worked cob test activity provided checkout team experience monitoring job analyzing failure process monitor app designer sql developer tectia client attend meeting client update behalf team employer client ibm india axa insurance uprade project peoplesoft hcm development upgrade tenure january responsibility assigned axa upgrade team developer upgrading peoplesoft version worked mapping tracing step peoplesoft upgrade project worked identifying different object like bolton custom peoplesoft modified object worked retrofitting peoplesoft object make development environment worked data reconciliation process every intermediate environment worked sqr analysis creating p query page record component menu etc worked batch process running intermediate phase testing purpose employer client ibm india axa insurance support project peoplesoft hcm enhancement support tenure october responsibility worked basic enhancement support worked creating p query created sqr modified sqr worked job management job scheduling peoplesoft iw give technical support team employer client accenture india florida palm project project peoplesoft finance implementation tenure june responsibility currently working developing interface report workflow form p query bi publisher scratch worked creating app engine app package component interface multilevel page xml report supporting resolving service request raised production release ticket expected resolved within stipulated timeline mentor associate developer supervise task achievement got acknowledgement client excellent uninterrupt ...
#        'rahul ahuja summary year experience peoplesoft technical consultant customization peoplesoft application using peoplesoft people tool indepth knowledge peopletools like application designer peoplecode application engine application package p security file layout xml publisher data mover integration broker workflow notification awe web service worked extensively application engine peoplecdoe file layout application package awe env refresh upgrade activity experience implementation project fair knowledge peoplesoft reporting tool psquery worked component interface excellent knowledge agile methodology self motivated person strong debugging problem solving analytical skill better understanding application development methodology technique tool ability write document clearly concisely goal oriented ability work within tight deadline posse excellent effective communication skill posse strong interpersonal leadership skill technical skill erp peoplesoft financials v people tool application designer p security application engine application package process scheduler people code workflow notification file layout data mover xml publisher integration broker sqr component interface web service workflow notification awe reporting tool sqr p query database oracle operating system window experience summary working peoplesoft technical lead team lead wipro limited pune jan till date worked senior peoplesoft technical consultant rotary international infotech pvt ltd pune jan jan worked software engineer hsbc glt hyderabad june jan peoplesoft technical consultant educational qualification bachelor engineering information technology nagpur university project profile project financial transformation platform ftp development uit testing production support client hsbc environment p fscm people tool database platform window role team member team size duration september december description hsbc leading bankproviding topclass banking facility service leveraging deep industry functional expertise leading technology practice global delivery model enable company achieve business goal transformation objectivesthis ftp project vast project consisting module used ledger purpose hsbc ftp involves customized module named reference data subdivided rule maintenance facility rmf rule table maintenance rtm reference data maintenance facility rdmf responsibility developing component comprising various page application engine sqrs per change request customize developed component sqr report application engine according change request make test materialplan validate development modification code involved code drop involved data migration using data mover script via ssh supporting various sit uat cycle module coordinating team per requirement schedule maintaining preventing defect member defect prevention control using hp quality centre examining system application issue problem improvement present option resolution project peoplesoft business improvement proposal p bips development uit testing production support client rotary headquarter evanston international office environment p fscm people tool database oracle platform window role team member team size duration january july description rotary international international service organization whose stated purpose bring together business professional leader order provide humanitarian service encourage high ethical standard vocation advance goodwill peace around world nonpolitical nonsectarian organization open people regardless race color creed religion gender political preference part team rotary international infotech private limited support operation rotary international globe responsibility developing maintaining custom component comprising various page application engine web service etc per requirement customize developed component application engine according change request make test materialplan validate development modification code involved code migration deployment involved data migration using da ...
#        'r ahmed peoplesoft technical consultant professional summary year experience peoplesoft consultant good experience peoplesoft fscm application technical experience support maintenance customization peoplesoft fscm application proficient application design creation various type definition implement validation according business requirement created modified component page record field process definition knowledge functional module like eprocurement purchasing payable module good exposure various peopletools like application designer application engine people code file layout component interface process scheduler proficient creation report using p query xml publisher involved implementation interface component interface posse effective communication problem solving team working skill professional experience working peoplesoft consultant virtusa june till date optimum solution pvt ltd educational profile bsccomputers mba affiliated jantuk technical skill set programming language people code erp application peoplesoft fscm tool people tool people tool app designer people code application engine ci file layout reporting tool p query xml publisher project project citi fscm duration april till date role peoplesoft technical consultant environment people tool peoplesoft fscm description project involves maintenance peoplesoft fscm module eprocurement purchase order account payable etc responsibility involved customizations enhancement also product support activity like job monitoring working incident interact onsite team clarify requirement customized system application designed many application scratch customized application modifying record page using application designer fulfill business user requirement tailored people code implement data validation created p query part business requirement involved enhancement create interface load positive pay p build staging table also involved enhancement create run control page glbus replace inactive glbus active glbus done customizations delivered app engine process used create payment voucher'],
#       dtype=object)

# %%
data_categories[3]
# Out:
#                                       lemmatized_text Catagory
# 58  chinna subbarayudu dob march nationality india...  workday
# 59  name gopi krishna reddy professional summery w...  workday
# 60  g himaja career objective work towards achievi...  workday
# 61  jyoti verma professional summary professional ...  workday
# 62  mooraboyina guravaiah workday integration spec...  workday
# 63  venkata saikrishna workday consultant profssio...  workday
# 64  workday hcm techno functional consultant rahul...  workday
# 65  ramesh workday hcm consultant professional sum...  workday
# 66  srikanth workday hcm consultant seeking suitab...  workday
# 67  workday hcm fcm name kumar s role workday cons...  workday
# 68  vinay kumar v workday functional consultant ex...  workday
# 69  hari krishna summary result oriented professio...  workday
# 70  harikrishna akula summary year experience arou...  workday
# 71  himamendu career objective continue growing kn...  workday
# 72  name j sumanth royal professional summary tota...  workday
# 73  madeeswar profile summary around year experien...  workday
# 74  name naresh babu cherukuri objective take resp...  workday
# 75  year experience workday hcm technical consulta...  workday
# 76  shireesh balasani hcm consultant profile summa...  workday
# 77  workday integration consultant name sri krishn...  workday
# 78  venkateswarlub workday consultant year experie...  workday

# %%
for i, category in enumerate(categories):
    print(data_categories[i])
# Out:
#                                       lemmatized_text    Catagory
# 24  anubhav kumar singh core competency scripting ...  Peoplesoft
# 25  classification internal classification interna...  Peoplesoft
# 26  sirazuddin bangalore india sirazuddin bangalor...  Peoplesoft
# 27  peoplesoft admin varkala vikas career objectiv...  Peoplesoft
# 28  peoplesoft administration vivekanand sayana ca...  Peoplesoft
# 29  hari narayana professional summary year experi...  Peoplesoft
# 30  murali professional summary year experience pe...  Peoplesoft
# 31  priyabrata hota career objective pursuing peop...  Peoplesoft
# 32  tanna sujatha objective seeking challenging ro...  Peoplesoft
# 33  c n c address manyata tech park nagavara banga...  Peoplesoft
# 34  profile summary year experience implementing u...  Peoplesoft
# 35  peoplesoft database administrator gangareddy p...  Peoplesoft
# 36  priyanka ramadoss mountpleasant coonoor nilgir...  Peoplesoft
# 37  peoplesoft administrator srinivask experience ...  Peoplesoft
# 38  vinod akkala peoplesoft dba admin professional...  Peoplesoft
# 39  peoplesoft adminpeoplesoft dba ganesh alladi c...  Peoplesoft
# 40  arun venu experience summary experience year m...  Peoplesoft
# 41  personal detail name pritam biswas date birth ...  Peoplesoft
# 42  rahul ahuja summary year experience peoplesoft...  Peoplesoft
# 43  r ahmed peoplesoft technical consultant profes...  Peoplesoft
#                                       lemmatized_text Catagory
# 0   name ravali p curriculum vitae specialization ...  Reactjs
# 1   susovan bag seeking challenging position field...  Reactjs
# 2   kanumuru deepak reddy career objective secure ...  Reactjs
# 3   haripriya battina experience ui developer reac...  Reactjs
# 4   kamalakar reddy linked professional summary ye...  Reactjs
# 5   naveen sadhu title software developer location...  Reactjs
# 6   pragnya pattnaik expertise around year experie...  Reactjs
# 7   sarala madasu sarala madasu geethika prestiger...  Reactjs
# 8   thirupathamma balla summary year experience re...  Reactjs
# 9   uideveloper react j developer name krishna pro...  Reactjs
# 10  uideveloper react j developer name krishna pro...  Reactjs
# 11  kotani durga prasad objective aspirant positio...  Reactjs
# 12  venkatalakshmi pedireddy software developer ex...  Reactjs
# 13  kambala sai surendra summary project basic kno...  Reactjs
# 14  mareedu lokesh babu professional overview arou...  Reactjs
# 15  mareedu lokesh babu professional overview arou...  Reactjs
# 16  md khizaruddin rauf experience currently worki...  Reactjs
# 17  pranish sonone career summary experience year ...  Reactjs
# 18  ranga gaganam professional summary professiona...  Reactjs
# 19  shaik abdul sharuk year experience wipro caree...  Reactjs
# 20  profile searching opportunity bring year exper...  Reactjs
# 21  maryala vinay reddy professional summary year ...  Reactjs
# 22  curriculum vitae anjani priyadarshini sr web d...  Reactjs
# 23  page name prabakaran title ui developer profes...  Reactjs
#                                       lemmatized_text       Catagory
# 44  anil kumar maddukuri sql msbi developer summar...  SQL_Developer
# 45  aradhana tripathi current location gachibowli ...  SQL_Developer
# 46  buddha vamsi career objective year experience ...  SQL_Developer
# 47  kamballa pradeep synopsis looking forward aspi...  SQL_Developer
# 48  resume name neeraj mishra experience summary y...  SQL_Developer
# 49  sql developer name bandi prem sai career objec...  SQL_Developer
# 50  sql server developer p syam kumar professional...  SQL_Developer
# 51  raju pavana kumari professional summary year p...  SQL_Developer
# 52  resume ramalakshmi k career objective professi...  SQL_Developer
# 53  name ramesh career objective contribute organi...  SQL_Developer
# 54  sql msbi developer sql msbi developer b vinod ...  SQL_Developer
# 55  hyderabad nazeer basha sql power bi developer ...  SQL_Developer
# 56  sql server developer priyanka l professional s...  SQL_Developer
# 57  career objective rewarding opportunity growtho...  SQL_Developer
#                                       lemmatized_text Catagory
# 58  chinna subbarayudu dob march nationality india...  workday
# 59  name gopi krishna reddy professional summery w...  workday
# 60  g himaja career objective work towards achievi...  workday
# 61  jyoti verma professional summary professional ...  workday
# 62  mooraboyina guravaiah workday integration spec...  workday
# 63  venkata saikrishna workday consultant profssio...  workday
# 64  workday hcm techno functional consultant rahul...  workday
# 65  ramesh workday hcm consultant professional sum...  workday
# 66  srikanth workday hcm consultant seeking suitab...  workday
# 67  workday hcm fcm name kumar s role workday cons...  workday
# 68  vinay kumar v workday functional consultant ex...  workday
# 69  hari krishna summary result oriented professio...  workday
# 70  harikrishna akula summary year experience arou...  workday
# 71  himamendu career objective continue growing kn...  workday
# 72  name j sumanth royal professional summary tota...  workday
# 73  madeeswar profile summary around year experien...  workday
# 74  name naresh babu cherukuri objective take resp...  workday
# 75  year experience workday hcm technical consulta...  workday
# 76  shireesh balasani hcm consultant profile summa...  workday
# 77  workday integration consultant name sri krishn...  workday
# 78  venkateswarlub workday consultant year experie...  workday

# %%
# for other theme, please run: mpl.pyplot.style.available
PLOT_PALETTE = 'tableau-colorblind10'
# for other color map, please run: mpl.pyplot.colormaps()
WORDCLOUD_COLOR_MAP = 'tab10_r'
plt.style.use(PLOT_PALETTE)
# %matplotlib inline
plt.figure(figsize=(40, 28))

for i, category in enumerate(categories):
    wc =  wordcloud(data_categories[i])

    plt.subplot(5, 5, i + 1).set_title(category)
    plt.imshow(wc)
    plt.axis('off')
    plt.plot()

plt.show()
plt.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [101], in <cell line: 9>()
#       7 plt.figure(figsize=(40, 28))
#       9 for i, category in enumerate(categories):
# ---> 10     wc =  wordcloud(data_categories[i])
#      12     plt.subplot(5, 5, i + 1).set_title(category)
#      13     plt.imshow(wc)
#
# Input In [97], in wordcloud(df)
#       1 def wordcloud(df):
# ----> 2     txt = nltk.word_tokenize(data_categories["lemmatized_text"].values)
#       3     wordcloud = WordCloud(
#       4         height=2000,
#       5         width=4000,
#       6         colormap=WORDCLOUD_COLOR_MAP
#       7     ).generate(txt)
#       9     return wordcloud
#
# TypeError: list indices must be integers or slices, not str

# %%
#nlp = spacy.load("en_core_web_sm")

# %%
#def tokenization(x):
    doc = nlp(x)
    tokens = [tok for tok in doc]
    return tokens

# %%
#data['tokenized'] = data['lemmatized_text'].apply(lambda x: tokenization(x))
# Out:
#                                               Resumes Catagory  \
# 0   Name: Ravali P                                ...  Reactjs
# 1   SUSOVAN  BAG    Seeking  a  challenging  posit...  Reactjs
# 2   Kanumuru Deepak Reddy   CAREER OBJECTIVE: To s...  Reactjs
# 3   HARIPRIYA BATTINA  Experience as UI Developer ...  Reactjs
# 4   KAMALAKAR REDDY. A  Linked In: https://www.lin...  Reactjs
# ..                                                ...      ...
# 74  Name : Naresh Babu Cherukuri Objective: To tak...  workday
# 75    3.3 years of IT experience as Workday HC...  workday
# 76  Shireesh Balasani                             ...  workday
# 77   Workday Integration Consultant Name         :...  workday
# 78  Venkateswarlu.B        Workday Consultant     ...  workday
#
#                                         Clean_Resumes  \
# 0   name ravali p curriculum vitae specialization ...
# 1   susovan bag seeking challenging position field...
# 2   kanumuru deepak reddy career objective secure ...
# 3   haripriya battina experience ui developer reac...
# 4   kamalakar reddy linked professional summary ye...
# ..                                                ...
# 74  name naresh babu cherukuri objective take resp...
# 75  years experience workday hcm technical consult...
# 76  shireesh balasani hcm consultant profile summa...
# 77  workday integration consultant name sri krishn...
# 78  venkateswarlub workday consultant years experi...
#
#                                       lemmatized_text  \
# 0   name ravali p curriculum vitae specialization ...
# 1   susovan bag seeking challenging position field...
# 2   kanumuru deepak reddy career objective secure ...
# 3   haripriya battina experience ui developer reac...
# 4   kamalakar reddy linked professional summary ye...
# ..                                                ...
# 74  name naresh babu cherukuri objective take resp...
# 75  year experience workday hcm technical consulta...
# 76  shireesh balasani hcm consultant profile summa...
# 77  workday integration consultant name sri krishn...
# 78  venkateswarlub workday consultant year experie...
#
#                                             tokenized
# 0   [name, ravali, p, curriculum, vitae, specializ...
# 1   [susovan, bag, seeking, challenging, position,...
# 2   [kanumuru, deepak, reddy, career, objective, s...
# 3   [haripriya, battina, experience, ui, developer...
# 4   [kamalakar, reddy, linked, professional, summa...
# ..                                                ...
# 74  [name, naresh, babu, cherukuri, objective, tak...
# 75  [year, experience, workday, hcm, technical, co...
# 76  [shireesh, balasani, hcm, consultant, profile,...
# 77  [workday, integration, consultant, name, sri, ...
# 78  [venkateswarlub, workday, consultant, year, ex...
#
# [79 rows x 5 columns]

# %%
data
# Out:
#                                               Resumes Catagory  \
# 0   Name: Ravali P                                ...  Reactjs
# 1   SUSOVAN  BAG    Seeking  a  challenging  posit...  Reactjs
# 2   Kanumuru Deepak Reddy   CAREER OBJECTIVE: To s...  Reactjs
# 3   HARIPRIYA BATTINA  Experience as UI Developer ...  Reactjs
# 4   KAMALAKAR REDDY. A  Linked In: https://www.lin...  Reactjs
# ..                                                ...      ...
# 74  Name : Naresh Babu Cherukuri Objective: To tak...  workday
# 75    3.3 years of IT experience as Workday HC...  workday
# 76  Shireesh Balasani                             ...  workday
# 77   Workday Integration Consultant Name         :...  workday
# 78  Venkateswarlu.B        Workday Consultant     ...  workday
#
#                                         Clean_Resumes  \
# 0   name ravali p curriculum vitae specialization ...
# 1   susovan bag seeking challenging position field...
# 2   kanumuru deepak reddy career objective secure ...
# 3   haripriya battina experience ui developer reac...
# 4   kamalakar reddy linked professional summary ye...
# ..                                                ...
# 74  name naresh babu cherukuri objective take resp...
# 75  years experience workday hcm technical consult...
# 76  shireesh balasani hcm consultant profile summa...
# 77  workday integration consultant name sri krishn...
# 78  venkateswarlub workday consultant years experi...
#
#                                       lemmatized_text
# 0   name ravali p curriculum vitae specialization ...
# 1   susovan bag seeking challenging position field...
# 2   kanumuru deepak reddy career objective secure ...
# 3   haripriya battina experience ui developer reac...
# 4   kamalakar reddy linked professional summary ye...
# ..                                                ...
# 74  name naresh babu cherukuri objective take resp...
# 75  year experience workday hcm technical consulta...
# 76  shireesh balasani hcm consultant profile summa...
# 77  workday integration consultant name sri krishn...
# 78  venkateswarlub workday consultant year experie...
#
# [79 rows x 4 columns]

# %%
df=data[["lemmatized_text","Catagory"]]
df
# Out:
#                                       lemmatized_text Catagory
# 0   name ravali p curriculum vitae specialization ...  Reactjs
# 1   susovan bag seeking challenging position field...  Reactjs
# 2   kanumuru deepak reddy career objective secure ...  Reactjs
# 3   haripriya battina experience ui developer reac...  Reactjs
# 4   kamalakar reddy linked professional summary ye...  Reactjs
# ..                                                ...      ...
# 74  name naresh babu cherukuri objective take resp...  workday
# 75  year experience workday hcm technical consulta...  workday
# 76  shireesh balasani hcm consultant profile summa...  workday
# 77  workday integration consultant name sri krishn...  workday
# 78  venkateswarlub workday consultant year experie...  workday
#
# [79 rows x 2 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
df["label_encoder"]=le.fit_transform(df.Catagory)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_29856\4186484618.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["label_encoder"]=le.fit_transform(df.Catagory)

# %%
le.classes_
# Out:
# array(['Peoplesoft', 'Reactjs', 'SQL_Developer', 'workday'], dtype=object)

# %%
df
# Out:
#                                       lemmatized_text Catagory  label_encoder
# 0   name ravali p curriculum vitae specialization ...  Reactjs              1
# 1   susovan bag seeking challenging position field...  Reactjs              1
# 2   kanumuru deepak reddy career objective secure ...  Reactjs              1
# 3   haripriya battina experience ui developer reac...  Reactjs              1
# 4   kamalakar reddy linked professional summary ye...  Reactjs              1
# ..                                                ...      ...            ...
# 74  name naresh babu cherukuri objective take resp...  workday              3
# 75  year experience workday hcm technical consulta...  workday              3
# 76  shireesh balasani hcm consultant profile summa...  workday              3
# 77  workday integration consultant name sri krishn...  workday              3
# 78  venkateswarlub workday consultant year experie...  workday              3
#
# [79 rows x 3 columns]

# %%
x = df['lemmatized_text'].values
y = df['label_encoder'].values

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
word_vectorizer = TfidfVectorizer(lowercase= True, sublinear_tf=True, stop_words='english')
word_vectorizer.fit(x)
WordFeatures = word_vectorizer.transform(x)

# %%
WordFeatures.shape
# Out:
# (79, 4223)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(WordFeatures,y,test_size=0.2,random_state=0,stratify=y)

# %%
X_train.shape,X_test.shape
# Out:
# ((63, 4223), (16, 4223))

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
lg = LogisticRegression()
lg.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
predict1 = lg.predict(X_test)
predict1
# Out:
# array([3, 1, 3, 2, 0, 1, 0, 0, 1, 1, 3, 1, 0, 2, 2, 3])

# %%
from sklearn.metrics import f1_score, confusion_matrix, accuracy_score, classification_report

# %%
accuracy_1 = accuracy_score(y_test,predict1)
accuracy_1
# Out:
# 1.0

# %%
sns.heatmap(confusion_matrix(y_test,predict1),annot=True,linewidths=1)
# Out:
# <AxesSubplot:>

# %%
print(classification_report(y_test,predict1))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         4
#            1       1.00      1.00      1.00         5
#            2       1.00      1.00      1.00         3
#            3       1.00      1.00      1.00         4
#
#     accuracy                           1.00        16
#    macro avg       1.00      1.00      1.00        16
# weighted avg       1.00      1.00      1.00        16

# %%
from sklearn.svm import SVC

# %%
sv = SVC()
sv.fit(X_train,y_train)
predict2 = sv.predict(X_test)

# %%
accuracy_2 = accuracy_score(y_test,predict2)
accuracy_2
# Out:
# 0.9375

# %%
cm2 = confusion_matrix(y_test,predict2)

# %%
sns.heatmap(cm2,annot=True,linewidths=1)
# Out:
# <AxesSubplot:>

# %%
print(classification_report(y_test,predict2))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         4
#            1       0.83      1.00      0.91         5
#            2       1.00      0.67      0.80         3
#            3       1.00      1.00      1.00         4
#
#     accuracy                           0.94        16
#    macro avg       0.96      0.92      0.93        16
# weighted avg       0.95      0.94      0.93        16

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier()
rf.fit(X_train,y_train)
predict3=rf.predict(X_test)

# %%
accuracy_3 = accuracy_score(y_test,predict3)
accuracy_3
# Out:
# 1.0

# %%
cm3 = confusion_matrix(y_test,predict3)
sns.heatmap(cm3,annot=True,linewidths=1)
# Out:
# <AxesSubplot:>

# %%
print(classification_report(y_test,predict3))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         4
#            1       1.00      1.00      1.00         5
#            2       1.00      1.00      1.00         3
#            3       1.00      1.00      1.00         4
#
#     accuracy                           1.00        16
#    macro avg       1.00      1.00      1.00        16
# weighted avg       1.00      1.00      1.00        16

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
nb=MultinomialNB()
nb.fit(X_train,y_train)
predict4=nb.predict(X_test)

# %%
accuracy_4 = accuracy_score(y_test,predict4)
accuracy_4
# Out:
# 0.9375

# %%
cm4 = confusion_matrix(y_test,predict4)
sns.heatmap(cm4,annot=True,linewidths=1)
# Out:
# <AxesSubplot:>

# %%
print(classification_report(y_test,predict4))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         4
#            1       1.00      1.00      1.00         5
#            2       1.00      0.67      0.80         3
#            3       0.80      1.00      0.89         4
#
#     accuracy                           0.94        16
#    macro avg       0.95      0.92      0.92        16
# weighted avg       0.95      0.94      0.93        16

# %%
# !pip install lightgbm
# Out:
# Requirement already satisfied: lightgbm in c:\users\dell\anaconda3\lib\site-packages (3.3.5)
# Requirement already satisfied: scikit-learn!=0.22.0 in c:\users\dell\anaconda3\lib\site-packages (from lightgbm) (1.1.3)
# Requirement already satisfied: wheel in c:\users\dell\anaconda3\lib\site-packages (from lightgbm) (0.37.1)
# Requirement already satisfied: scipy in c:\users\dell\anaconda3\lib\site-packages (from lightgbm) (1.7.3)
# Requirement already satisfied: numpy in c:\users\dell\anaconda3\lib\site-packages (from lightgbm) (1.21.5)
# Requirement already satisfied: joblib>=1.0.0 in c:\users\dell\anaconda3\lib\site-packages (from scikit-learn!=0.22.0->lightgbm) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\dell\anaconda3\lib\site-packages (from scikit-learn!=0.22.0->lightgbm) (3.1.0)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dell\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dell\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dell\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dell\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dell\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dell\anaconda3\lib\site-packages)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier,GradientBoostingClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier

# %%
dt = DecisionTreeClassifier(max_depth=3)
dt.fit(X_train,y_train)
predict5=dt.predict(X_test)

# %%
accuracy_5 = accuracy_score(y_test,predict5)
accuracy_5
# Out:
# 1.0

# %%
cm5 = confusion_matrix(y_test,predict5)
sns.heatmap(cm5,annot=True,linewidths=1)
# Out:
# <AxesSubplot:>

# %%
print(classification_report(y_test,predict5))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         4
#            1       1.00      1.00      1.00         5
#            2       1.00      1.00      1.00         3
#            3       1.00      1.00      1.00         4
#
#     accuracy                           1.00        16
#    macro avg       1.00      1.00      1.00        16
# weighted avg       1.00      1.00      1.00        16

# %%
ab = AdaBoostClassifier()
ab.fit(X_train,y_train)
predict6=ab.predict(X_test)

# %%
accuracy_6 = accuracy_score(y_test,predict6)
accuracy_6
# Out:
# 0.75

# %%
cm6 = confusion_matrix(y_test,predict6)
sns.heatmap(cm6,annot=True,linewidths=1)
# Out:
# <AxesSubplot:>

# %%
print(classification_report(y_test,predict6))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         4
#            1       0.56      1.00      0.71         5
#            2       1.00      1.00      1.00         3
#            3       1.00      1.00      1.00         4
#
#     accuracy                           0.75        16
#    macro avg       0.64      0.75      0.68        16
# weighted avg       0.61      0.75      0.66        16
# C:\Users\Dell\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Dell\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Dell\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
gd = GradientBoostingClassifier()
gd.fit(X_train,y_train)
predict7 = gd.predict(X_test)

# %%
accuracy_7 = accuracy_score(y_test,predict7)
accuracy_7
# Out:
# 1.0

# %%
cm7 = confusion_matrix(y_test,predict7)
sns.heatmap(cm7,annot=True,linewidths=1)
# Out:
# <AxesSubplot:>

# %%
print(classification_report(y_test,predict7))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         4
#            1       1.00      1.00      1.00         5
#            2       1.00      1.00      1.00         3
#            3       1.00      1.00      1.00         4
#
#     accuracy                           1.00        16
#    macro avg       1.00      1.00      1.00        16
# weighted avg       1.00      1.00      1.00        16

# %%
xg = XGBClassifier()
xg.fit(X_train,y_train)
predict8 = xg.predict(X_test)

# %%
accuracy_8 = accuracy_score(y_test,predict8)
accuracy_8
# Out:
# 1.0

# %%
cm8 = confusion_matrix(y_test,predict8)
sns.heatmap(cm8,annot=True,linewidths=1)
# Out:
# <AxesSubplot:>

# %%
print(classification_report(y_test,predict8))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         4
#            1       1.00      1.00      1.00         5
#            2       1.00      1.00      1.00         3
#            3       1.00      1.00      1.00         4
#
#     accuracy                           1.00        16
#    macro avg       1.00      1.00      1.00        16
# weighted avg       1.00      1.00      1.00        16

# %%
lgbm = LGBMClassifier()
lgbm.fit(X_train,y_train)
predict9 = lgbm.predict(X_test)

# %%
accuracy_9 = accuracy_score(y_test,predict9)
accuracy_9
# Out:
# 1.0

# %%
cm9 = confusion_matrix(y_test,predict9)
sns.heatmap(cm9,annot=True,linewidths=1)
# Out:
# <AxesSubplot:>

# %%
table = {'Classifier' : ['Logistic Regression','SVM Classifier','Random Forest Classifier', 'Naive-Bayes Classifier','Decision Tree Classifier','AdaBoost Classifier', 'Gradient Boosting Classifier', 'Xtreme Gradient Boosting Classifier', 'Light Gradient Boosting Classifier'], 'Accuracy' : [accuracy_1, accuracy_2, accuracy_3, accuracy_4, accuracy_5, accuracy_6, accuracy_7, accuracy_8, accuracy_9]} #'Precision Score' : [precision_1, precision_2, precision_3, precision_4, precision_5, precision_6, precision_7, precision_8, precision_9], 'Recall Score' : [recall_1, recall_2, recall_3, recall_4, recall_5, recall_6, recall_7, recall_8, recall_9], 'F1_Score' : [f1_1, f1_2, f1_3, f1_4, f1_5, f1_6, f1_7, f1_8, f1_9]}
table = pd.DataFrame(table)
table.sort_values(["Accuracy"],inplace = True, ignore_index=True, ascending=False)
table
# Out:
#                             Classifier  Accuracy
# 0                  Logistic Regression    1.0000
# 1             Random Forest Classifier    1.0000
# 2             Decision Tree Classifier    1.0000
# 3         Gradient Boosting Classifier    1.0000
# 4  Xtreme Gradient Boosting Classifier    1.0000
# 5   Light Gradient Boosting Classifier    1.0000
# 6                       SVM Classifier    0.9375
# 7               Naive-Bayes Classifier    0.9375
# 8                  AdaBoost Classifier    0.7500

# %%
plt.figure(figsize=(10,8))
ax = sns.barplot(data=table,x='Accuracy',y='Classifier', palette="gist_rainbow", ci=None)
plt.yticks(fontsize=12);
for i in ax.containers:
    ax.bar_label(i,fontsize=13)

# %%
import pickle

# %%
xgboost_model= xg.fit(X_train,y_train)

# %%
pickle.dump(xgboost_model, open("xgboost_model.pkl", 'wb')) #Saving the model

# %%
model = pickle.load(open("xgboost_model.pkl", 'rb')) #To load saved model from local directory

# %%
model.predict(X_test)
# Out:
# array([3, 1, 3, 2, 0, 1, 0, 0, 1, 1, 3, 1, 0, 2, 2, 3], dtype=int64)

# %%
data
# Out:
#                                               Resumes Catagory  \
# 0   Name: Ravali P                                ...  Reactjs
# 1   SUSOVAN  BAG    Seeking  a  challenging  posit...  Reactjs
# 2   Kanumuru Deepak Reddy   CAREER OBJECTIVE: To s...  Reactjs
# 3   HARIPRIYA BATTINA  Experience as UI Developer ...  Reactjs
# 4   KAMALAKAR REDDY. A  Linked In: https://www.lin...  Reactjs
# ..                                                ...      ...
# 74  Name : Naresh Babu Cherukuri Objective: To tak...  workday
# 75    3.3 years of IT experience as Workday HC...  workday
# 76  Shireesh Balasani                             ...  workday
# 77   Workday Integration Consultant Name         :...  workday
# 78  Venkateswarlu.B        Workday Consultant     ...  workday
#
#                                         Clean_Resumes  \
# 0   name ravali p curriculum vitae specialization ...
# 1   susovan bag seeking challenging position field...
# 2   kanumuru deepak reddy career objective secure ...
# 3   haripriya battina experience ui developer reac...
# 4   kamalakar reddy linked professional summary ye...
# ..                                                ...
# 74  name naresh babu cherukuri objective take resp...
# 75  years experience workday hcm technical consult...
# 76  shireesh balasani hcm consultant profile summa...
# 77  workday integration consultant name sri krishn...
# 78  venkateswarlub workday consultant years experi...
#
#                                       lemmatized_text
# 0   name ravali p curriculum vitae specialization ...
# 1   susovan bag seeking challenging position field...
# 2   kanumuru deepak reddy career objective secure ...
# 3   haripriya battina experience ui developer reac...
# 4   kamalakar reddy linked professional summary ye...
# ..                                                ...
# 74  name naresh babu cherukuri objective take resp...
# 75  year experience workday hcm technical consulta...
# 76  shireesh balasani hcm consultant profile summa...
# 77  workday integration consultant name sri krishn...
# 78  venkateswarlub workday consultant year experie...
#
# [79 rows x 4 columns]

# %%
import en_core_web_sm
nlp = en_core_web_sm.load()

# %%
def extract_skills(resume_text):

    nlp_text = nlp(resume_text)
    noun_chunks = nlp_text.noun_chunks

    # removing stop words and implementing word tokenization
    tokens = [token.text for token in nlp_text if not token.is_stop]
            
    # reading the csv file
    data = pd.read_csv("https://raw.githubusercontent.com/MoinDalvs/Resume_Classification/main/skills.csv") 
            
    # extract values
    skills = list(data.columns.values)
            
    skillset = []
            
    # check for one-grams (example: python)
    for token in tokens:
        if token.lower() in skills:
            skillset.append(token)
            
    # check for bi-grams and tri-grams (example: machine learning)
    for token in noun_chunks:
        token = token.text.lower().strip()
        if token in skills:
            skillset.append(token)
            
    return [i.capitalize() for i in set([i.lower() for i in skillset])]

# %%
data.columns.values
# Out:
# array(['Resumes', 'Catagory', 'Clean_Resumes', 'lemmatized_text'],
#       dtype=object)

# %%
extract_skills(data["Resumes"][4])
# Out:
# ['Ubuntu',
#  'Html',
#  'Javascript',
#  'Analysis',
#  'Technical',
#  'English',
#  'Visual',
#  'Updates',
#  'System',
#  'Content',
#  'Design',
#  'Html5',
#  'Jira',
#  'Js',
#  'Communication',
#  'Photoshop',
#  'Data collection',
#  'Windows',
#  'Ui',
#  'Coding',
#  'Agile',
#  'Css']

# %%
word_vectorizer = TfidfVectorizer(lowercase= True, max_features=2000, sublinear_tf=True, stop_words='english')
word_vectorizer.fit(x)
WordFeatures = word_vectorizer.transform(x)

# %%
WordFeatures.shape
# Out:
# (79, 2000)

# %%
X_train,X_test,y_train,y_test = train_test_split(WordFeatures,y,test_size=0.2,random_state=0,stratify=y)

# %%
ab = AdaBoostClassifier()
ab.fit(X_train,y_train)
predict6=ab.predict(X_test)

# %%
accuracy_6=accuracy_score(y_test,predict6)
accuracy_6
# Out:
# 0.75

# %%
dt = DecisionTreeClassifier(max_depth=3)
dt.fit(X_train,y_train)
predict5=dt.predict(X_test)

# %%
accuracy_5=accuracy_score(y_test,predict5)
accuracy_5
# Out:
# 0.9375

# %%
nb=MultinomialNB()
nb.fit(X_train,y_train)
predict4=nb.predict(X_test)

# %%
accuracy_4=accuracy_score(y_test,predict4)
accuracy_4
# Out:
# 1.0

# %%
sv = SVC()
sv.fit(X_train,y_train)
predict2 = sv.predict(X_test)

# %%
accuracy_2=accuracy_score(y_test,predict2)
accuracy_2
# Out:
# 1.0

# %%
rf = RandomForestClassifier()
rf.fit(X_train,y_train)
predict3=rf.predict(X_test)

# %%
accuracy_3=accuracy_score(y_test,predict3)
accuracy_3
# Out:
# 1.0

# %%
lgbm = LGBMClassifier()
lgbm.fit(X_train,y_train)
predict9 = lgbm.predict(X_test)

# %%
accuracy_9=accuracy_score(y_test,predict9)
accuracy_9
# Out:
# 1.0

# %%
xg = XGBClassifier()
xg.fit(X_train,y_train)
predict8 = xg.predict(X_test)

# %%
accuracy_8=accuracy_score(y_test,predict8)
accuracy_8
# Out:
# 1.0

# %%
lg = LogisticRegression()
lg.fit(X_train,y_train)
predict1 = lg.predict(X_test)

# %%
accuracy_1=accuracy_score(y_test,predict1)
accuracy_1
# Out:
# 1.0

# %%
gd = GradientBoostingClassifier()
gd.fit(X_train,y_train)
predict7 = gd.predict(X_test)

# %%
accuracy_7=accuracy_score(y_test,predict7)
accuracy_7
# Out:
# 1.0

# %%
table1 = {'Classifier' : ['Logistic Regression','SVM Classifier','Random Forest Classifier', 'Naive-Bayes Classifier','Decision Tree Classifier','AdaBoost Classifier', 'Gradient Boosting Classifier', 'Xtreme Gradient Boosting Classifier', 'Light Gradient Boosting Classifier'], 'Accuracy' : [accuracy_1, accuracy_2, accuracy_3, accuracy_4, accuracy_5, accuracy_6, accuracy_7, accuracy_8, accuracy_9]} #'Precision Score' : [precision_1, precision_2, precision_3, precision_4, precision_5, precision_6, precision_7, precision_8, precision_9], 'Recall Score' : [recall_1, recall_2, recall_3, recall_4, recall_5, recall_6, recall_7, recall_8, recall_9], 'F1_Score' : [f1_1, f1_2, f1_3, f1_4, f1_5, f1_6, f1_7, f1_8, f1_9]}
table1 = pd.DataFrame(table1)
table1.sort_values(["Accuracy"],inplace = True, ignore_index=True, ascending=False)
table1
# Out:
#                             Classifier  Accuracy
# 0                  Logistic Regression    1.0000
# 1                       SVM Classifier    1.0000
# 2             Random Forest Classifier    1.0000
# 3               Naive-Bayes Classifier    1.0000
# 4         Gradient Boosting Classifier    1.0000
# 5  Xtreme Gradient Boosting Classifier    1.0000
# 6   Light Gradient Boosting Classifier    1.0000
# 7             Decision Tree Classifier    0.9375
# 8                  AdaBoost Classifier    0.7500

# %%
plt.figure(figsize=(10,8))
ax = sns.barplot(data=table1,x='Accuracy',y='Classifier', palette="gist_rainbow", ci=None)
plt.yticks(fontsize=12);
for i in ax.containers:
    ax.bar_label(i,fontsize=13)
